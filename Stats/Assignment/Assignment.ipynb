# %% [markdown]
# ### Module 4: Essential Statistics & Mathematics for DataScience

# %% [markdown]
# # Theoretical Assignments:
#
# * Explain Key Statistical Concepts
#
# 1. Measures of central trendency
# Descriptive statistics summarize and describe the main features of a dataset.
#
# Mean: The average of all values
# Median: The middle value in sorted data
# Mode: The most frequent value
#
# Used to understand the overall behavior of data.
#
# 2. Measures of Dispersion
# These describe how spread out the data is.
#
# Range: Difference between maximum and minimum values
# Variance: Average of squared deviations from the mean
# Standard Deviation: Square root of variance
#
# Helps understand variability in data.
#
# 3. Probability
# Probability measures the likelihood of an event occurring.
#
# Value ranges from 0 to 1
# 0 → Impossible event
# 1 → Certain event
#
# Used for predictions and decision-making.
#
# 4. Probability Distributions
# These describe how data values are distributed.
#
# Normal Distribution: Bell-shaped, symmetric distribution
# Binomial Distribution: Used for binary outcomes (success/failure)
# Poisson Distribution: Used for count-based events
#
# Helps model real-world data patterns.
#
# 5. Correlation
# Correlation measures the relationship between two variables.
#
# Positive correlation: Both variables increase together
# Negative correlation: One increases, the other decreases
# Zero correlation: No relationship
#
# Value ranges from -1 to +1
#
# 6. Hypothesis Testing
# A statistical method used to make decisions based on data.
#
# Null Hypothesis (H₀): Assumes no effect or no difference
# Alternative Hypothesis (H₁): Assumes there is an effect
#
# Helps test claims using sample data.
#
# 7. Confidence Interval
# A range of values used to estimate a population parameter.
#
# Example: 95% confidence interval
#
# Means we are 95% confident that the true value lies within the range.
#
# 8. Sampling
# Sampling is the process of selecting a subset of data from a population.
#
# Used when analyzing the entire population is not possible
#
# Helps save time and resources.
#
# 9. Central Limit Theorem (CLT)
# The CLT states that the sampling distribution of the mean approaches a normal distribution as sample size increases.
#
# Important for making inferences about population.
#
# 10. Outliers
# Outliers are extreme values that differ significantly from other observations.
#
# Can affect mean and standard deviation.

# %% [markdown]
# Q Explain Key Statistical Concepts
#
# 1.Population and Sample
# Population: The complete set of all items or people you want to study. Example: All customers of a car rental company.
#
# Sample: A smaller subset taken from the population. Example: Rental durations of 50 customers.
#
# Why sample? Because studying the entire population is difficult, costly, or time-consuming.
#
# 2.Variable
# A variable is any characteristic or value that can change.
#
# Examples:
#
# Age
#
# Height
#
# Rental duration
#
# Salary
#
# Types:
#
# Numerical variables → numbers (age, marks)
#
# Categorical variables → categories (gender, color)
#
# 3.Mean (Average)
# The mean is the average value.
#
# Formula:
#
# Mean = Sum of all values / Number of values
#
# Use: Shows the central value of data.
#
# 4.Median
# The median is the middle value when data is arranged in order.
#
# Example:
#
# Data: 1, 3, 5 → Median = 3
#
# If even numbers:
#
# Data: 1, 3, 5, 7 Median = (3+5)/2 = 4
#
# Use: Better when data has outliers.
#
# 5.Mode
# The mode is the value that appears most frequently.
#
# Example:
#
# Data: 2, 3, 3, 5, 6 Mode = 3
#
# Use: Shows most common value.
#
# 6.Range
# The range shows the spread of data.
#
# Formula:
#
# Range=Maximum−Minimum
#
# Example:
#
# Data: 2, 5, 9
#
# Range = 9 − 2 = 7
#
# 7.Variance
# Variance measures how far values are spread from the mean.
#
# Formula:
#
# Variance = ∑(x−mean)^2 ? n​Higher variance → more spread Lower variance → less spread
#
# 8.Standard Deviation
# Standard deviation is the square root of variance.
#
# Standard deviation= sqrt(Variance)​Use: Most important measure of data spread.
#
# Low SD → data close to mean High SD → data widely spread
#
# 9.Probability
# Probability measures the chance of an event.
#
# Formula:
#
# Probability = Favorable outcomes / Total outcomes
#
# 10.Distribution
# Distribution shows how data values are spread.
#
# Common type: Normal Distribution (Bell curve)
#
# Properties:
#
# Mean = Median = Mode
#
# Symmetrical shape
#
# Used in ML, statistics, and real-world analysis.
#
# 11.Outliers
# Outliers are unusual or extreme values.
#
# Example:
#
# Data: 2, 3, 4, 5, 100
#
# Here, 100 is an outlier.
#
# Outliers affect mean and analysis.
#
# 12.Frequency
# Frequency = how many times a value occurs.
#
# Example:
#
# Data: 2, 2, 3, 4
#
# Frequency of 2 = 2

# %% [markdown]
# 1. Business Problem: A car rental company wants to analyze the rental durations of its customers to understand the typical rental period and optimize its pricing and fleet
# management strategies. Data: Let's consider the rental durations (in days) for asample of 50 customers:
# 3, 2, 5, 4, 7, 2, 3, 3, 1, 6, 4, 2, 3, 5, 2, 4, 2, 1, 3, 5, 6, 3, 2, 1, 4, 2, 4, 5, 3, 2, 7, 2, 3, 4, 5, 1, 6, 2, 4, 3, 5, 3, 2, 4, 2, 6, 3, 2, 4, 5
# Question:
# a. Mean: What is the average rental duration for customers at the car rental company?
# b. Median: What is the typical or central rental duration experiencedbycustomers?
# c. Mode: Are there any recurring or most frequently occurring rental durations for customers?
# By answering these questions using the mean, median, and mode, the car rental company can gain insights into the average rental duration, understand the most common rental periods, and make informed decisionsregarding pricing, fleet size, and availability. Additionally, this analysiscan help the company optimize resource allocation, plan for peak demandperiods, and enhance customer satisfaction by aligning service offeringswith customers' typical rental needs.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
df = pd.DataFrame([3, 2, 5, 4, 7, 2, 3, 3, 1, 6, 4, 2, 3, 5, 2, 4, 2, 1, 3, 5, 6, 3, 2, 1, 4, 2, 4, 5, 3, 2, 7, 2, 3, 4, 5, 1, 6, 2, 4, 3, 5, 3, 2, 4, 2, 6, 3, 2, 4, 5])

# %%
df
# Out:
#     0
# 0   3
# 1   2
# 2   5
# 3   4
# 4   7
# 5   2
# 6   3
# 7   3
# 8   1
# 9   6
# 10  4
# 11  2
# 12  3
# 13  5
# 14  2
# 15  4
# 16  2
# 17  1
# 18  3
# 19  5
# 20  6
# 21  3
# 22  2
# 23  1
# 24  4
# 25  2
# 26  4
# 27  5
# 28  3
# 29  2
# 30  7
# 31  2
# 32  3
# 33  4
# 34  5
# 35  1
# 36  6
# 37  2
# 38  4
# 39  3
# 40  5
# 41  3
# 42  2
# 43  4
# 44  2
# 45  6
# 46  3
# 47  2
# 48  4
# 49  5

# %%
print("Mean:  ", df[0].mean())
print("Median:", df[0].median())
print("Mode:  ", df[0].mode()[0])
# Out:
# Mean:   3.44
# Median: 3.0
# Mode:   2

# %% [markdown]
# 2. An e-commerce platform wants to analyze the delivery times of its shipments tounderstand the variability in order fulfillment and optimize its logistics operations.
# Data:
# Let's consider the delivery times (in days) for a sample of 50 shipments:
# 3, 5, 2, 4, 6, 2, 3, 4, 2, 5, 7, 2, 3, 4, 2, 4, 2, 3, 5, 6, 3, 2, 1, 4, 2, 4, 5, 3, 2, 7, 2, 3, 4, 5, 1, 6, 2, 4, 3, 5, 3, 2, 4, 2, 6, 3, 2, 4, 5, 3
#
# Questions:
# a. Range: What is the range of the delivery times?
# b. Variance: What is the variance of the delivery times?
# c. Standard Deviation: What is the standard deviation of the deliverytimes?By answering these questions using different measures of dispersion, the e- commerce platform can gain insights into the variability in delivery times, identify any bottlenecks in the logistics process, and make informed decisionsregarding shipment tracking,customer expectations, and service level agreements.

# %%
df = pd.DataFrame({'Days': [3, 5, 2, 4, 6, 2, 3, 4, 2, 5, 7, 2, 3, 4, 2, 4, 2, 3, 5, 6, 3, 2, 1, 4, 2, 4, 5, 3, 2, 7, 2, 3, 4, 5, 1, 6, 2, 4, 3, 5, 3, 2, 4, 2, 6, 3, 2, 4, 5, 3]})

# %%
df
# Out:
#     Days
# 0      3
# 1      5
# 2      2
# 3      4
# 4      6
# 5      2
# 6      3
# 7      4
# 8      2
# 9      5
# 10     7
# 11     2
# 12     3
# 13     4
# 14     2
# 15     4
# 16     2
# 17     3
# 18     5
# 19     6
# 20     3
# 21     2
# 22     1
# 23     4
# 24     2
# 25     4
# 26     5
# 27     3
# 28     2
# 29     7
# 30     2
# 31     3
# 32     4
# 33     5
# 34     1
# 35     6
# 36     2
# 37     4
# 38     3
# 39     5
# 40     3
# 41     2
# 42     4
# 43     2
# 44     6
# 45     3
# 46     2
# 47     4
# 48     5
# 49     3

# %%
print("Range:", df['Days'].max() - df['Days'].min())
print("Variance:", df.var())
print("Standard Deviation:", df.std())
# Out:
# Range: 6
# Variance: Days    2.336327
# dtype: float64
# Standard Deviation: Days    1.528505
# dtype: float64

# %% [markdown]
# 3. A company wants to analyze the monthly revenue generated by one of its productsto understand its performance and variability.
# Data: Let's consider the monthly revenue (in thousands of dollars) for the past 12months:
# $120, $150, $110, $135, $125, $140, $130, $155, $115, $145, $135, $130
#
# Questions:
# a. Measure of Central Tendency: What is the average monthly revenuefor the product?
# b. Measure of Dispersion: What is the range of monthly revenue for theproduct?
# By answering these questions, the company can gain insights into the averagerevenue generated by the product and understand the range or variabilityinitsmonthly revenue, which can help with financial planning, forecasting, andevaluating the product's performance.

# %%
df = pd.DataFrame({"Month":[120, 150, 110, 135, 125, 140, 130, 155, 115, 145, 135, 130]})

# %%
print("Average Monthly Revenue (Mean):", df['Month'].mean())
print("Range of Monthly Revenue:", df['Month'].max() - df['Month'].min())
# Out:
# Average Monthly Revenue (Mean): 132.5
# Range of Monthly Revenue: 45

# %% [markdown]
# 4. A transportation company wants to analyze the fuel efficiency of its vehicle fleet toidentify any variations across different vehicle models. Data: Let's consider the fuel efficiency (in miles per gallon, mpg) for a sample of 50 vehicles:
# Model A: 30, 32, 33, 28, 31, 30, 29, 30, 32, 31,
# Model B: 25, 27, 26, 23, 28, 24, 26, 25, 27, 28,
# Model C: 22, 23, 20, 25, 21, 24, 23, 22, 25, 24,
# Model D: 18, 17, 19, 20, 21, 18, 19, 17, 20, 19,
# Model E: 35, 36, 34, 35, 33, 34, 32, 33, 36, 34
#
# Questions:
# a. Measure of Central Tendency: What is the average fuel efficiencyfor eachvehicle model?
# b. Measure of Dispersion: What is the range of fuel efficiency for eachvehicle model?
# c. Measure of Dispersion: What is the variance of the fuel efficiencyfor eachvehicle model?
# By answering these questions, the transportation company can gaininsights into the average fuel efficiency of different vehicle models, understand the variations or spread in the fuel efficiency, and make
# informed decisions regarding fleet management, vehicle selection, andfuel consumption optimization.

# %%
models = pd.DataFrame({
"A":[30,32,33,28,31,30,29,30,32,31],
"B":[25,27,26,23,28,24,26,25,27,28],
"C":[22,23,20,25,21,24,23,22,25,24],
"D":[18,17,19,20,21,18,19,17,20,19],
"E":[35,36,34,35,33,34,32,33,36,34]
})

# %%
for model, values in models.items():
    print("\nModel", model)
    print("Mean:", values.mean())
    print("Range:", values.max() - values.min())
    print("Variance:", values.var(ddof=0))          # Population Variance
# Default VAriance in pandas is sample variance (ddof=1)
# Out:
# Model A
# Mean: 30.6
# Range: 5
# Variance: 2.0400000000000005
#
# Model B
# Mean: 25.9
# Range: 5
# Variance: 2.49
#
# Model C
# Mean: 22.9
# Range: 5
# Variance: 2.4899999999999998
#
# Model D
# Mean: 18.8
# Range: 4
# Variance: 1.56
#
# Model E
# Mean: 34.2
# Range: 4
# Variance: 1.5599999999999998

# %% [markdown]
# 5. A manufacturing company wants to analyze the defect rates of its production line to identify the frequency of different types of defects.
# Data: Let's consider the types of defects and their corresponding frequencies observed in a sample of 200 products:
# Defect Type: A, B, C, D, E, F, G
# Frequency: 30, 40, 20, 10, 45, 25, 30
#
# Questions:
# a. Bar Chart: Create a bar chart to visualize the frequency of different defect types.
# b. Most Common Defect: Which defect type has the highest frequency?
# c. Histogram: Create a histogram to represent the defect frequencies.
# By answering these questions using a bar chart and histogram, the manufacturingcompany can visually understand the distribution of defect types, identifythemost common defect, and prioritize quality control efforts to address the prevalent issues.

# %%
defects = ['A','B','C','D','E','F','G']
freq = [30,40,20,10,45,25,30]

# Bar chart
plt.bar(defects, freq)
plt.title("Defect Frequency - Bar Chart")
plt.xlabel("Defect Types")
plt.ylabel("Frequency")
plt.show()


# Histogram
plt.hist(freq)
plt.title("Defect Frequency - Histofram")
plt.xlabel("Frequency")
plt.ylabel("Count")
plt.show()

# Most common defect
max_defect = defects[np.argmax(freq)]       # argmax = Returns the indices of the maximum values along an axis.
print("Most Common Defect:", max_defect)
max_freq = max(freq)
print("Frequency:", max_freq)
# Out:
# Most Common Defect: E
# Frequency: 45

# %% [markdown]
# 6. A survey was conducted to analyze the satisfaction ratings of customers onascaleof 1 to 5 for a specific product. Data: Let's consider the satisfaction ratings from 200 customers:
# Ratings:
# 4, 5, 3, 4, 4, 3, 2, 5, 4, 3, 5, 4, 2, 3, 4, 5, 3, 4, 5, 3, 4, 3, 2, 4, 5, 3, 4, 5, 4, 3, 3, 4, 5, 2, 3, 4, 4, 3, 5, 4, 3, 4, 5, 4, 2, 3, 4, 5, 3, 4, 5, 4, 3, 4, 5, 3, 4, 5, 4, 3, 3, 4, 5, 2, 3, 4, 4, 3, 5, 4, 3, 4, 5, 4, 2, 3, 4, 5, 3, 4, 5, 4, 3, 4, 5, 3, 4, 5, 4, 3, 3, 4, 5, 2, 3, 4, 4, 3, 5, 4
#
# Questions:
# a. Skewness: Calculate the skewness of the satisfaction ratings.
# b. Kurtosis: Calculate the kurtosis of the satisfaction ratings.
# c. Interpretation: Based on the skewness and kurtosis values, what canbeinferred about the satisfaction ratings distribution?
# By answering these questions using measures of skewness and kurtosis, thesurvey can assess the skewness and peakedness of the satisfaction ratings, determine if the ratings are skewed towards positive or negative evaluations, andunderstand the distribution characteristics of customer satisfaction.

# %%
ratings = [4, 5, 3, 4, 4, 3, 2, 5, 4, 3, 5, 4, 2, 3, 4, 5, 3, 4, 5, 3, 4, 3, 2, 4, 5, 3, 4, 5, 4, 3, 3, 4, 5, 2, 3, 4, 4, 3, 5, 4, 3, 4, 5, 4, 
           2, 3, 4, 5, 3, 4, 5, 4, 3, 4, 5, 3, 4, 5, 4, 3, 3, 4, 5, 2, 3, 4, 4, 3, 5, 4, 3, 4, 5, 4, 2, 3, 4, 5, 3, 4, 5, 4, 3, 4, 5, 3, 4, 5, 
           4, 3, 3, 4, 5, 2, 3, 4, 4, 3, 5, 4]

# %%
skewness = stats.skew(ratings)
kurtosis = stats.kurtosis(ratings)

print("Skewness:", skewness)
print("kurtosis:", kurtosis)
# Out:
# Skewness: -0.20773281879682218
# kurtosis: -0.767917404014467

# %% [markdown]
# 7. A research study wants to analyze the weight distribution of a sample of
# individuals to assess their health and body composition.
# Data: Let's consider the weights (in kilograms) of a sample of 100 individuals:
# Weights:
# 55, 60, 62, 65, 68, 70, 72, 75, 78, 80, 82, 85, 88, 90, 92, 95, 100, 105, 110, 115, 120, 125, 130, 135, 140, 145, 150, 155, 160, 165, 170, 175, 180, 185, 190, 195, 200, 205, 210, 215, 220, 225, 230, 235, 240, 245, 250, 255, 260, 265, 270, 275, 280, 285, 290, 295, 300, 305, 310, 315, 320, 325, 330, 335, 340, 345, 350, 355, 360, 365, 370, 375, 380, 385, 390, 395, 400, 405, 410, 415, 420, 425, 430, 435, 440, 445, 450, 455, 460, 465, 470, 475, 480, 485, 490, 495, 500, 505, 510, 515
#
# Questions:
# a. Quartiles: Calculate the first quartile (Q1), median (Q2), and thirdquartile(Q3) of the weight distribution.
# b. Percentiles: Calculate the 15th percentile, 50th percentile, and 85th percentile of the weight distribution.
# c. Interpretation: Based on the quartiles and percentiles, what can be inferredabout the weight distribution of the individuals?
# By answering these questions using quartiles and percentiles, the researchstudycan understand the weight distribution and identify the weight ranges at different percentiles, such as underweight, normal weight, overweight, and obese categories.

# %%
weights = [55, 60, 62, 65, 68, 70, 72, 75, 78, 80, 82, 85, 88, 90, 92, 95, 100, 105, 110, 115, 120, 125, 130, 135, 140, 145, 150, 
           155, 160, 165, 170, 175, 180, 185, 190, 195, 200, 205, 210, 215, 220, 225, 230, 235, 240, 245, 250, 255, 260, 265, 270, 
           275, 280, 285, 290, 295, 300, 305, 310, 315, 320, 325, 330, 335, 340, 345, 350, 355, 360, 365, 370, 375, 380, 385, 390, 
           395, 400, 405, 410, 415, 420, 425, 430, 435, 440, 445, 450, 455, 460, 465, 470, 475, 480, 485, 490, 495, 500, 505, 510, 515]

df = pd.DataFrame({"weights": weights})


Q1 = df['weights'].quantile(0.25)
Q2 = df['weights'].quantile(0.50)
Q3 = df['weights'].quantile(0.75)

P15 = df['weights'].quantile(0.15)
P50 = df['weights'].quantile(0.50)
P85 = df['weights'].quantile(0.85)

print("Q1:", Q1)
print("Median:", Q2)
print("Q3:", Q3)

print("15th Percentile:", P15)
print("50th Percentile:", P50)
print("85th Percentile:", P85)
# Out:
# Q1: 143.75
# Median: 267.5
# Q3: 391.25
# 15th Percentile: 94.55
# 50th Percentile: 267.5
# 85th Percentile: 440.74999999999994

# %% [markdown]
# 8. A researcher wants to examine the relationship between the hours spent studyingand the exam scores of a group of students.
# Data: Let's consider the number of hours spent studying and the correspondingexam scores for a sample of 30 students:
# Hours Spent Studying: 10, 12, 15, 18, 20, 22, 25, 28, 30, 32, 35, 38, 40, 42, 45, 48, 50, 52, 55, 58, 60, 62, 65, 68, 70, 72, 75, 78, 80, 82
# Exam Scores: 60, 65, 70, 75, 80, 82, 85, 88, 90, 92, 93, 95, 96, 97, 98, 99, 100, 102, 105, 106, 107, 108, 110, 112, 114, 115, 116, 118, 120, 122
#
# Question:
# Calculate the correlation coefficient between the hours spent studying and the exam scores. Interpret the value of the correlation coefficient and explain the nature of the relationship between studying hours and exam scores.
# By analyzing the correlation coefficient, the researcher can determine the strengthanddirection of the relationship between studying hours and exam scores. This informationcan provide insights into the effectiveness of studying and help students and educatorsmake informed decisions about study habits and academic performance.

# %%
hours = [10, 12, 15, 18, 20, 22, 25, 28, 30, 32, 35, 38, 40, 42, 45, 48, 50, 52, 55, 58, 60, 62, 65, 68, 70, 72, 75, 78, 80, 82]
scores = [60, 65, 70, 75, 80, 82, 85, 88, 90, 92, 93, 95, 96, 97, 98, 99, 100, 102, 105, 106, 107, 108, 110, 112, 114, 115, 116, 118, 120, 122]

correlation = np.corrcoef(hours, scores)[0,1]
print("Correlation coefficient:", correlation)
# Out:
# Correlation coefficient: 0.9772950830186736

# %% [markdown]
# Interpretation: The correlation coefficient is 0.9773, which indicates a very strong positive relationship between hours spent studying and exam scores. This means that as
#                 the number of study hours increases, exam scores also tend to increase. Therefore, studying more is strongly associated with better academic performance.

# %% [markdown]
# 9. A multiple-choice test consists of 10 questions, each with four possible answers. If astudent randomly guesses on each question, what is the probability of gettingat least
# 8 questions correct? Data:
# Number of questions (n) = 10,
# Number of possible answers per question (k) = 4

# %%
from scipy.stats import binom               # we used binomial for Fixed number of trials

n = 10
p = 1/4

prob = sum(binom.pmf(k, n, p) for k in range(8,11))
print("Probability of atleast 8 correct:", prob)
# Out:
# Probability of atleast 8 correct: 0.0004158020019531251

# %% [markdown]
# Interpretation: The probability of getting at least 8 correct answers by random guessing is approximately 0.000416. This is a very low probability, which indicates
#                 that achieving such a high score by guessing alone is highly unlikely.

# %% [markdown]
# 10. The lifetimes of a certain brand of light bulbs are normally distributed with a mean of 1000 hours and a standard deviation of 100 hours. What is the probability that a randomly selected light bulb lasts between 900 and 1100 hours?
# Data: Meanlifetime(μ) = 1000 hours,
#       Standard deviation (σ) = 100 hours,
#       Lifetime range (lower limit x1, upper limit x2)

# %%
from scipy.stats import norm

mean = 1000
std = 100

prob = norm.cdf(1100, mean, std) - norm.cdf(900, mean, std)

print("Probability", prob)
# Out:
# Probability 0.6826894921370859

# %% [markdown]
# 11. A study is conducted to estimate the mean height of a population. Arandomsampleof 100 individuals is selected, and their heights are measured. Calculate a 95%  confidence interval for the population mean height, given that the sample meanheight is 170 cm and the sample standard deviation is 8 cm.
# Data: Sample size(n) = 100,
#       Sample mean (x̄) = 170 cm,
#       Sample standard deviation (s) = 8 cm,
#       Confidencelevel = 95%
#
# Explanation: In this problme, we use a sample to estimate the population mean height. By calculating a confidence interval, we provide a range of plausible values for the population mean. The 95% confidence level indicates that we are 95% confident that the true population mean height falls within the calculated interval.

# %%
n = 100
mean = 170
std = 8

z = 1.96

margin = z * (std/np.sqrt(n))

lower = mean - margin
upper = mean + margin

print("Confidence Interval:", lower, "to", upper)
# Out:
# Confidence Interval: 168.432 to 171.568

# %% [markdown]
# 12. A manufacturing company claims that the average weight of its product is 500grams. To test this claim, a random sample of 25 products is selected, and their
# weights are measured. The sample mean weight is found to be 510 grams with a sample standard deviation of 20 grams. Perform a hypothesis test to determine if
# there is evidence to support the company's claim.
# Data: Sample size (n) = 25,
#       Sample mean (x̄) = 510 grams,
#       Sample standard deviation (s) = 20 grams,
#       Population mean (μ) = 500 grams
#
# Explanation: In this problem, we are conducting a hypothesis test to assess whether the sample mean weight provides evidence to support the company's claim about the population mean weight. The null hypothesis (H0) assumes that the population mean weight is equal to the claimed value, while the alternative hypothesis (Ha) suggests otherwise.

# %%
sample_mean = 510
population_mean = 500
std = 20
n = 25

z = (sample_mean - population_mean)/(std/np.sqrt(n))            # Standard Error (SE) = (std/np.sqrt(n)) to calculate Mean uncertainty
print("Z-score:", z)
# Out:
# Z-score: 2.5

# %% [markdown]
# 13.A researcher wants to test whether a new teaching method improves student performance. A random sample of 50 students is divided into two groups: onegrouptaught using the new method and the other using the traditional method. The averagetest scores of the two groups are compared. State the null and alternative hypothesesfor this study.
# Data: Sample size (n) = 50,
#       Test scores of the two groups
#
# Explanation: In this problem, we are interested in comparing the means of twogroups (new method vs. traditional method). The null hypothesis (H0) states that there is no significant difference between the means, while the alternative hypothesis (Ha) suggests that there is a significant difference.

# %%
group_new = np.array([85, 88, 79, 92, 85, 90, 84, 87, 83, 89, 
                      91, 78, 86, 88, 82, 85, 87, 90, 84, 86, 
                      89, 81, 85, 87, 88])

group_traditional = np.array([78, 82, 75, 80, 83, 79, 81, 77, 85, 76, 
                            82, 80, 79, 81, 78, 84, 77, 80, 79, 82, 
                            75, 81, 80, 78, 76])

# 1. Perform the Independent Samples t-test
# equal_var = True assumes the populations have the same variance
t_stat, p_value = stats.ttest_ind(group_new, group_traditional)


print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# 2. Interpret the results (using alpha = 0.05)
alpha = 0.05
if p_value < alpha:
    print("Conclusion: Reject the Null Hypothesis (Significant improvement).")
else:
    print("Conclusion: Fail to reject the Null Hypothesis (No significant difference).")
# Out:
# T-statistic: 7.2364
# P-value: 0.0000
# Conclusion: Reject the Null Hypothesis (Significant improvement).

# %% [markdown]
# 14. A survey is conducted to estimate the proportion of people in a city who support aparticular policy. A random sample of 500 individuals is surveyed, and 320of themexpress support for the policy. Calculate a 90% confidence interval for the
# population proportion, given the sample proportion.
# Data: Sample size (n) = 500,
#       Number of successes (x) = 320,
#       Confidence level = 90%
#
# Explanation: In this problem, we aim to estimate the population proportionbasedon the sample proportion. By constructing a confidence interval, we providearange of plausible values for the population proportion. The 90% confidence level indicates that we are 90% confident that the true population proportion falls within the calculated interval.

# %%
n = 500
x = 320

p = x/n         # p = proportion
z = 1.645

margin = z * np.sqrt((p*(1-p)/n))        # Margin of Error

lower = p - margin
upper = p + margin

print("Confidence Interval:", lower, "to", upper)
# Out:
# Confidence Interval: 0.6046880144993233 to 0.6753119855006767

# %% [markdown]
# 15. A company sells smartphones, and the number of defects per batch follows a
# Poisson distribution with a mean of 2 defects. What is the probability of havingexactly 3 defects in a randomly selected batch?
# Data: Mean number of defects (λ) = 2,
#       Number of defects (x) = 3
#
# Explanation: The problem involves a discrete distribution (Poisson) becauseweare dealing with the count of defects in a batch of smartphones. The Poisson
# distribution models the probability of a given number of events occurring within a fixed interval of time or space.

# %%
from scipy.stats import poisson

lam = 2
x = 3

prob = poisson.pmf(x, lam)

print("Probability:", prob)
# Out:
# Probability: 0.18044704431548356
