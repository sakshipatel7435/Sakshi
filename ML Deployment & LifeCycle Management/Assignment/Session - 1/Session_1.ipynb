# %% [markdown]
# ### Tasks

# %% [markdown]
# * 1. Write a short paragraph explaining the difference between training and deployment of a machine learning model, using an example from an app you use daily (such as Instagram's feed ranking or Zomato's food recommendations).

# %% [markdown]
# * 2. List three real-world examples where ML models are deployed in popular apps (for example, spam detection in WhatsApp, personalized playlists in Spotify, or fraud detection in Paytm), and for each, briefly describe how users interact with the ML-powered feature.

# %% [markdown]
# * 3. Imagine you are building a movie recommendation feature for a BookMyShow-like app. Describe whether you would use online or offline deployment for your ML model and justify your choice in 3-4 sentences.<br><br><em><strong>Hint:</strong> Consider how quickly recommendations need to update and how often the model is retrained.</em>

# %% [markdown]
# * 4. Given a list of 10 user reviews for a restaurant (as text), write a Python function that simulates batch prediction by categorizing each review as 'positive' or 'negative' based on whether it contains the word 'good'. Print the results for all reviews.<br><br><em><strong>Constraint:</strong> Do not use any external ML libraries; just use basic string operations.</em>

# %% [markdown]
# * 5. Think of a common deployment challenge (such as model version mismatch, slow predictions, or scaling to many users) that could happen if you were deploying an ML model in a Flipkart-like app. Briefly describe the challenge and suggest one solution to handle it.
