# %% [markdown]
# ### Tasks

# %% [markdown]
# * 1. nstall FastAPI and Uvicorn in a new Python virtual environment, then create a file called insta_like_api.py with a FastAPI app that exposes a root ('/') endpoint returning {'message': 'Instagram Like Counter API running'}.

# %%
# python -m venv venv
# .\venv\Scripts\Activate.ps1
# pip install fastapi uvicorn

# %% [markdown]
# * 2. Create a POST endpoint /predict-likes in your FastAPI app that accepts a JSON payload with 'current_likes' (int) and 'new_likes' (int), and returns the updated total likes as JSON.

# %% [markdown]
# * 3. Use Postman to send a POST request to your /predict-likes endpoint with current_likes: 1200 and new_likes: 350, and verify that the response correctly returns the sum in the expected JSON format.

# %% [markdown]
# * 4. Modify your FastAPI endpoint to handle the case where either 'current_likes' or 'new_likes' is missing in the request, and return an error message with status code 400.<br><br><em><strong>Hint:</strong> Use Pydantic models and FastAPI's validation features to enforce required fields.</em>

# %% [markdown]
# * 5. Compare FastAPI and Flask by writing a one-paragraph summary of which framework you would choose to build an IPL fantasy points prediction API, and why.
