# %% [markdown]
# ### Tasks

# %% [markdown]
# * 1. Create a Streamlit app that lets the user upload a CSV file using st.file_uploader, then reads the file into a Pandas DataFrame and displays the entire table using st.dataframe.

# %% [markdown]
# * 2. After uploading a CSV in your Streamlit app, display only the top 10 rows using df.head(10) and show the total number of rows and columns just below the table.

# %% [markdown]
# * 3. Add a dropdown in your Streamlit app that lists all column names from the uploaded CSV; when a user selects a column, display only that column's data as a table.

# %% [markdown]
# * 4. Implement a basic filter in your Streamlit app: let the user type a search term, and display only the rows where any cell in the DataFrame contains that term (case-insensitive).<br><br><em><strong>Hint:</strong> Use df.apply with axis=1 to check if the search term is present in any column for each row.</em>
