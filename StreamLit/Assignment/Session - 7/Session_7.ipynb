# %% [markdown]
# ### Tasks

# %% [markdown]
# * 1. Plan and outline a Streamlit app that helps users track their daily water intake, listing the main UI sections, input types, and at least two charts you would include.

# %% [markdown]
# * 2. Build the UI for a Flipkart-style product rating analyzer in Streamlit: add a sidebar with a file uploader for CSV, a dropdown to select product categories, and a main area to display results.

# %% [markdown]
# * 3. Write Streamlit code to accept user input for their top 5 favorite songs (like a Spotify playlist), process the data to count how many times each artist appears, and display the result as a bar chart.

# %% [markdown]
# * 4. Redesign your Streamlit app layout using columns and st.expander to make the interface cleaner and more user-friendly.<br><br><em><strong>Hint:</strong> Use st.columns to arrange input and output side by side, and st.expander to hide advanced options.</em>

# %% [markdown]
# * 5. Test your Streamlit app by entering invalid or missing data (such as uploading an empty file or leaving a required input blank) and note any errors or crashes you find. Suggest one best practice to handle such cases in a production app.
