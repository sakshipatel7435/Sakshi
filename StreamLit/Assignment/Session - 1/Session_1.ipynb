# %% [markdown]
# ### Tasks

# %% [markdown]
# * 1. Install Streamlit using pip in a new virtual environment and verify the installation by running 'streamlit --version' in your terminal.

# %%
# !python -m venv env

# %%
# env\Scripts\Activate.ps1

# %%
# !pip install streamlit

# %%
# !python -m streamlit --version
# Out:
# Streamlit, version 1.56.0

# %% [markdown]
# * 2. Set up a new project folder called insta_stats_app, create a file app.py inside it, and write code to display 'Welcome to Insta Stats!' using Streamlit's st.write().

# %% [markdown]
# * 3. Run your app.py using the 'streamlit run app.py' command and open the app in your browser to see the output.

# %% [markdown]
# * 4. Edit your app.py to change the welcome message to 'Instagram Follower Stats Coming Soon!' and observe how Streamlit automatically refreshes the browser when you save the file.<br><br><em><strong>Hint:</strong> No need to restart the server—just save and watch the update.</em>

# %% [markdown]
# * 5. Use ChatGPT to find three real-world use cases for Streamlit in popular Indian apps (like Zomato, Flipkart, or Spotify) and write one line explaining how Streamlit could help in each scenario.
