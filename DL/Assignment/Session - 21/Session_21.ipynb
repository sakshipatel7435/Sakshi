# %% [markdown]
# ### Tasks

# %% [markdown]
# * 1. Create a new Keras Sequential model and add a Conv2D layer with 32 filters, a 3x3 kernel, and ReLU activation for image input shape (32, 32, 3) as used in CIFAR-10.

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.models import Sequential

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.cifar10.load_data()
# Out:
# C:\Users\patel prit\AppData\Roaming\Python\Python312\site-packages\keras\src\datasets\cifar.py:18: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   d = cPickle.load(f, encoding="bytes")

# %%
# (x_train, x_valid) = X_train[5000:], X_train[:5000]
# (y_train, y_valid) = y_train[5000:], y_train[:5000]

# %%
X_train = X_train/255.0
X_test = X_test/255.0

# %%
model_1 = Sequential([
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3))
])
# Out:
# C:\Users\patel prit\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# * 2. Add a MaxPooling2D layer after your Conv2D layer to reduce spatial dimensions, then flatten the output and add a Dense layer with 64 units and ReLU activation.

# %%
model_2 = Sequential([
    layers.Input(shape=(32, 32, 3)),
    layers.Conv2D(32, (3, 3), activation='relu'),
    layers.MaxPooling2D(2, 2),
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# %% [markdown]
# * 3. Insert a BatchNormalization layer after the Conv2D and before MaxPooling2D, and add a Dropout layer (rate 0.3) after flattening to help prevent overfitting.<br><br><em><strong>Hint:</strong> BatchNorm stabilizes training, Dropout randomly disables neurons during training.</em>

# %%
model_3 = Sequential([
    layers.Input(shape=(32, 32, 3)),
    layers.Conv2D(32, (3, 3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Flatten(),
    layers.Dropout(0.3),
    layers.Dense(64, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# %% [markdown]
# * 4. Compile your model using the 'adam' optimizer, 'categorical_crossentropy' loss, and track 'accuracy' as a metric. Then, train the model for 5 epochs using random data shaped like CIFAR-10 images and labels.<br><br><em><strong>Constraint:</strong> Use numpy to generate random input data and one-hot encoded labels for testing if you don't want to download the full CIFAR-10 dataset.</em>

# %%
model_3.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model_3.fit(
    X_train, y_train, 
    epochs=5, 
    validation_data = (X_test, y_test),
    batch_size=32)
# Out:
# Epoch 1/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 32s 19ms/step - accuracy: 0.5081 - loss: 1.4011 - val_accuracy: 0.5578 - val_loss: 1.2512
# Epoch 2/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 16ms/step - accuracy: 0.6151 - loss: 1.0923 - val_accuracy: 0.6074 - val_loss: 1.1267
# Epoch 3/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.6585 - loss: 0.9644 - val_accuracy: 0.6148 - val_loss: 1.1297
# Epoch 4/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 24s 15ms/step - accuracy: 0.6939 - loss: 0.8667 - val_accuracy: 0.5763 - val_loss: 1.2718
# Epoch 5/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 22s 14ms/step - accuracy: 0.7235 - loss: 0.7868 - val_accuracy: 0.6082 - val_loss: 1.2215

# %% [markdown]
# * 5. Use ChatGPT or Copilot to suggest one improvement to your CNN architecture for better accuracy on image classification, and implement the suggested change in your code.

# %%
model_5 = Sequential([
    layers.Input(shape=(32, 32, 3)),
    
    layers.Conv2D(32, (3, 3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),
    
    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.3),
    

    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.4),
    layers.Dense(10, activation='softmax')
])

# %%
model_5.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model_5.summary()
# Out:
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_11 (Conv2D)              │ (None, 30, 30, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 30, 30, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
history_improved = model_5.fit(
    X_train, 
    y_train, 
    epochs=5,
    validation_data=(X_test, y_test),
    batch_size=32
)
# Out:
# Epoch 1/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 35s 21ms/step - accuracy: 0.4564 - loss: 1.5652 - val_accuracy: 0.4667 - val_loss: 1.6116
# Epoch 2/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 34s 22ms/step - accuracy: 0.5736 - loss: 1.2092 - val_accuracy: 0.5249 - val_loss: 1.3713
# Epoch 3/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 35s 23ms/step - accuracy: 0.6123 - loss: 1.0997 - val_accuracy: 0.6217 - val_loss: 1.0655
# Epoch 4/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.6374 - loss: 1.0331 - val_accuracy: 0.5627 - val_loss: 1.2778
# Epoch 5/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 29s 19ms/step - accuracy: 0.6560 - loss: 0.9806 - val_accuracy: 0.6852 - val_loss: 0.8901

# %% [markdown]
# Initially, the CNN had only one hidden convolutional layer with 32 filters of size 3×3. I then added a second hidden convolutional layer with 64 filters of size 3×3 to improve the model's feature extraction capability and potentially achieve better image classification accuracy.
