# %% [markdown]
# ### Tasks

# %% [markdown]
# * 1. Load the ResNet50 model with pretrained ImageNet weights using Keras, print the model summary, and count how many layers are trainable by default.

# %%
import tensorflow as tf
from tensorflow.keras.applications import ResNet50

# %%
model = ResNet50(weights='imagenet')

# %%
model.summary()
# Out:
# Model: "resnet50"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_pad           │ (None, 230, 230,  │          0 │ input_layer[0][0] │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_conv (Conv2D) │ (None, 112, 112,  │      9,472 │ conv1_pad[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %%
trainable_layers = sum(layer.trainable for layer in model.layers)

# %%
print("Total Layers:", len(model.layers))
print("Trainable Layers:", trainable_layers)
# Out:
# Total Layers: 177
# Trainable Layers: 177

# %% [markdown]
# **Observation:** The pretrained ResNet50 model loaded successfully with 25.6 million parameters, where 25.58 million are trainable, making it suitable for transfer learning and image classification tasks.

# %% [markdown]
# * 2. Use the VGG16 model (with include_top=False) as a feature extractor to process a batch of 10 images from any public dataset (e.g., CIFAR-10 or your own downloaded images), and print the shape of the extracted features.<br><br><em><strong>Hint:</strong> Use keras.applications.vgg16.preprocess_input() before passing images to the model.</em>

# %%
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.applications import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input

# %%
(X_train, y_train), (_, _) = cifar10.load_data()

img = X_train[:10]
# Out:
# C:\Users\patel prit\AppData\Roaming\Python\Python312\site-packages\keras\src\datasets\cifar.py:18: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   d = cPickle.load(f, encoding="bytes")

# %%
img = tf.image.resize(img, (224,224))
img = img.numpy()
img = preprocess_input(img)

# %%
base_model = VGG16(weights='imagenet', include_top=False)

# %%
features = base_model.predict(img)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step

# %%
print("Features Shape:", features.shape)
# Out:
# Features Shape: (10, 7, 7, 512)

# %% [markdown]
# * 3. Freeze all layers of the InceptionV3 model except the last 30 layers, then add a custom Dense output layer for 5-class classification, and print the number of trainable parameters.<br><br><em><strong>Hint:</strong> Use model.trainable = False, then set trainable=True for the last layers as needed.</em>

# %%
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model

# %%
base_model = InceptionV3(
    weights='imagenet',
    include_top=False,
    input_shape=(299,299,3)
)

for layer in base_model.layers:
    layer.trainable=False

for layer in base_model.layers[-30:]:
    layer.trainable=True

x = GlobalAveragePooling2D()(base_model.output)
x = Dense(128, activation='relu')(x)
output = Dense(5, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 299, 299,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 149, 149,  │        864 │ input_layer_2[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 149, 149,  │         96 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %%
trainable_params = sum(tf.keras.backend.count_params(w) for w in model.trainable_weights)
print("Trainable Parameters:", trainable_params)
# Out:
# Trainable Parameters: 5418949

# %% [markdown]
# * 4. Fine-tune a pretrained ResNet50 model by unfreezing the last 10 layers and training it on a small subset (at least 2 classes) of the Food-101 or any other food image dataset for 2 epochs. Report the training accuracy after the last epoch.

# %%
from tensorflow.keras.datasets import cifar10

# %%
(X_train, y_train), (_, _) = cifar10.load_data()

mask = (y_train.flatten()==0) | (y_train.flatten()==1)

X_train = X_train[mask]
y_train = y_train[mask]

X_train = X_train[:500]
y_train = y_train[:500]

X_train = tf.image.resize(X_train, (224,224))
X_train = X_train.numpy() / 255.0

# %%
base_model = ResNet50(
    weights='imagenet',
    include_top=False,
    input_shape=(224,224,3)
)

# %%
for layer in base_model.layers:
    layer.trainable=False

for layer in base_model.layers[-10:]:
    layer.trainable=True

# %%
x = GlobalAveragePooling2D()(base_model.output)
output = Dense(2, activation='softmax')(x)

model = Model(base_model.input, output)

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(X_train, y_train, epochs=2, batch_size=8)

print("\nTraining Accuracy:", history.history['accuracy'][-1])
# Out:
# Epoch 1/2
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 32s 406ms/step - accuracy: 0.6400 - loss: 0.6797
# Epoch 2/2
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 25s 392ms/step - accuracy: 0.7880 - loss: 0.4676
#
# Training Accuracy: 0.7879999876022339

# %% [markdown]
# * 5. Use ChatGPT or Copilot to generate Keras code that loads the InceptionV3 model, freezes all layers, adds a custom classification head with a Dropout layer, and compiles the model for binary classification. Paste the generated code and note any changes you made to get it running.

# %%
from tensorflow.keras.layers import Dropout

# %%
base_model = InceptionV3(
    weights='imagenet',
    include_top=False,
    input_shape=(299,299,3)
)

# %%
for layer in base_model.layers:
    layer.trainable=False

# %%
x = GlobalAveragePooling2D()(base_model.output)
x = Dropout(0.5)(x)
output = Dense(1, activation='sigmoid')(x)

model = Model(base_model.input, output)

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_4       │ (None, 299, 299,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_94 (Conv2D)  │ (None, 149, 149,  │        864 │ input_layer_4[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 149, 149,  │         96 │ conv2d_94[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %% [markdown]
# **Changes made:**
# 1. Added input_shape=(299,299,3).
# 2. Used include_top=False to remove the original classifier.
# 3. Added GlobalAveragePooling2D before the Dense layer.
# 4. Added Dropout(0.5) to reduce overfitting.
# 5. Used Dense(1, activation='sigmoid') for binary classification.
# 6. Compiled the model using binary_crossentropy and the Adam optimizer.
