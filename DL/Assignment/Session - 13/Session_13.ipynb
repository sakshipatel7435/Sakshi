# %% [markdown]
# ### Tasks

# %% [markdown]
# * 1. Install TensorFlow and Keras in your Python environment, then create a new file called spotify_like_classifier.py.

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.callbacks import EarlyStopping

# %%
np.random.seed(42)
tf.random.set_seed(42)

# %%
X = np.random.rand(100, 2)
y = np.random.randint(0, 2, size=(100, 1))

# %%
X_train, X_val = X[:80], X[80:]
y_train, y_val = y[:80], y[80:]

# %% [markdown]
# * 2. In spotify_like_classifier.py, define a Sequential model in Keras with three Dense layers: the first with 16 units and 'relu' activation, the second with 8 units and 'relu', and the third with 1 unit and 'sigmoid' activation.

# %%
model = Sequential([
    Input(shape=(2,), name='input_features'),
    Dense(16, activation='relu', name='hidden_layer_1'),
    Dense(8, activation='relu', name='hidden_layer_2'),
    Dense(1, activation='sigmoid', name='output_layer'),
])

# %% [markdown]
# * 3. Compile your model using the 'adam' optimizer, 'binary_crossentropy' loss, and include 'accuracy' as a metric.

# %%
model.compile(
    optimizer = 'adam',
    loss = 'binary_crossentropy',
    metrics = ['accuracy']
)

# %% [markdown]
# * 4. Simulate a small dataset: generate 100 random user profiles (features: listening_time, liked_genre_score) and a binary label (liked_song: 0 or 1). Train your model using model.fit() for 20 epochs and print the accuracy after training.<br><br><em><strong>Hint:</strong> Use numpy to generate random data for features and labels.</em>

# %%
import tensorflow as tf

# %%
print("* Starting Training:")
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=20,
    batch_size=16,
    callbacks=[early_stopping]
)

train_acc = history.history['accuracy'][-1]
val_acc = history.history['val_accuracy'][-1]

print("\nFinal Results")
print(f"Total Epochs Run:          {len(history.history['loss'])}")
print(f"Final Training Accuracy:   {train_acc:.4f} ({train_acc * 100:.2f}%)")
print(f"Final Validation Accuracy: {val_acc:.4f} ({val_acc * 100:.2f}%)")
# Out:
# * Starting Training:
# Epoch 1/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.5750 - loss: 0.6823 - val_accuracy: 0.4500 - val_loss: 0.7121
# Epoch 2/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5750 - loss: 0.6797 - val_accuracy: 0.4500 - val_loss: 0.7155
# Epoch 3/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5750 - loss: 0.6777 - val_accuracy: 0.4500 - val_loss: 0.7189
# Epoch 4/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5750 - loss: 0.6758 - val_accuracy: 0.4500 - val_loss: 0.7223
# Epoch 4: early stopping
# Restoring model weights from the end of the best epoch: 1.
#
# Final Results
# Total Epochs Run:          4
# Final Training Accuracy:   0.5750 (57.50%)
# Final Validation Accuracy: 0.4500 (45.00%)

# %% [markdown]
# * 5. Add a callback to your fit() call that stops training early if the validation loss does not improve for 3 epochs.<br><br><em><strong>Hint:</strong> Use Keras' EarlyStopping callback and set patience=3.</em>

# %% [markdown]
# early_stopping = EarlyStopping(
#     monitor='val_loss',
#     patience=3,
#     restore_best_weights=True,
#     verbose=1
# )

# %%
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=3,
    restore_best_weights=True,
    verbose=1
)
