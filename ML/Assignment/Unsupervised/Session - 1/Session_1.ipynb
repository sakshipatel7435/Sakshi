# %% [markdown]
# ### Tasks

# %% [markdown]
# * 1. Write a short Python script that generates a random dataset of 10 users, each with two features: number of daily app opens and average session duration (in minutes). Print the dataset as a list of dictionaries.

# %%
import random

# %%
user_dataset = [
    {
        "user_id": f"User_{i+1}",
        "daily_app_opens": random.randint(1, 25),
        "avg_session_duration_mins": round(random.uniform(0.5, 45.0), 2)
    }
    for i in range(10)
]

# %%
print(*user_dataset, sep="\n")
# Out:
# {'user_id': 'User_1', 'daily_app_opens': 22, 'avg_session_duration_mins': 26.61}
# {'user_id': 'User_2', 'daily_app_opens': 25, 'avg_session_duration_mins': 37.2}
# {'user_id': 'User_3', 'daily_app_opens': 8, 'avg_session_duration_mins': 0.96}
# {'user_id': 'User_4', 'daily_app_opens': 25, 'avg_session_duration_mins': 22.66}
# {'user_id': 'User_5', 'daily_app_opens': 14, 'avg_session_duration_mins': 4.17}
# {'user_id': 'User_6', 'daily_app_opens': 7, 'avg_session_duration_mins': 42.12}
# {'user_id': 'User_7', 'daily_app_opens': 7, 'avg_session_duration_mins': 2.13}
# {'user_id': 'User_8', 'daily_app_opens': 12, 'avg_session_duration_mins': 9.71}
# {'user_id': 'User_9', 'daily_app_opens': 24, 'avg_session_duration_mins': 22.51}
# {'user_id': 'User_10', 'daily_app_opens': 16, 'avg_session_duration_mins': 32.72}

# %% [markdown]
# * 2. Create a table comparing supervised and unsupervised learning in at least 4 points, using real-world app examples (like Instagram feed ranking for supervised, Spotify playlist grouping for unsupervised).

# %% [markdown]
# | Feature | Supervised Learning | Unsupervised Learning |
# | :--- | :--- | :--- |
# | **Data Requirement** | Requires fully labeled training data (input-output pairs). | Processes unlabeled data containing only inputs. |
# | **Primary Goal** | To predict specific target values or classifications. | To discover hidden structures, groupings, or relationships. |
# | **Algorithm Types** | Linear Regression, Support Vector Machines, Random Forest. | K-Means Clustering, PCA, Hierarchical Clustering. |
# | **Real-World App Example** | **Instagram Feed Ranking**: Uses post histories and user tags (labels) to predict and rank contents you are likely to enjoy. | **Spotify Playlist Grouping**: Bundles songs into generic mood profiles based on raw track similarities without pre-defined tags. |

# %% [markdown]
# * 3. Given a list of 8 products with their price and number of reviews, use any method (even manual grouping) to segment them into 2-3 clusters based on similarity. Explain your reasoning for each cluster.<br><br><em><strong>Hint:</strong> Think about which products are similar in both price and popularity (reviews).</em>

# %%
products = [
    {'product': 'A', 'price': 15, 'reviews': 5000},
    {'product': 'B', 'price': 1200, 'reviews': 45},
    {'product': 'C', 'price': 20, 'reviews': 4800},
    {'product': 'D', 'price': 1300, 'reviews': 30},
    {'product': 'E', 'price': 400, 'reviews': 1200},
    {'product': 'F', 'price': 18, 'reviews': 5200},
    {'product': 'G', 'price': 1150, 'reviews': 40},
    {'product': 'H', 'price': 380, 'reviews': 1150}
]

# %% [markdown]
# * 4. List 3 scenarios in Zomato, Flipkart, or Spotify where unsupervised learning could be used to discover hidden patterns or group users/items. For each, briefly describe what data would be needed and what insights might be found.

# %% [markdown]
# Here is the short version of **Task 4**:
#
# ### 1. Flipkart: Customer Value Segmentation
#
# * **Data Needed:** Total spend, purchase frequency, and cart abandonment rate.
# * **Insights Found:** Groups users into personas like "VIP Shoppers" or "Discount Seekers" to target them with tailored push notifications.
#
# ### 2. Spotify: Mood & Vibe Clustering
#
# * **Data Needed:** Track features like tempo (BPM), energy, danceability, and acousticness.
# * **Insights Found:** Automatically groups songs into specific "vibes" (e.g., *Chill Study* vs. *High-Energy Workout*) for automated radio recommendations.
#
# ### 3. Zomato: Restaurant Profiling
#
# * **Data Needed:** Average cost for two, cuisines, peak order hours, and ratings.
# * **Insights Found:** Clusters restaurants into types like *Late-Night Budget Fast Food* or *Weekend Luxury Dining* to optimize hyper-local homepage feeds.

# %% [markdown]
# * 5. Find a real-world dataset (CSV or Excel) online that could be used for customer segmentation (for example, mall customers, e-commerce users, or music listeners). Share the link and describe the structure: how many features, what kind of data, and whether it’s labeled or unlabeled.<br><br><em><strong>Hint:</strong> Use Kaggle, UCI Machine Learning Repository, or Google to find your dataset.</em>

# %% [markdown]
# Dataset Name: Mall Customer Segmentation Data
# Link: https://www.kaggle.com/datasets/vjchoudhary7/customer-segmentation-tutorial-in-python
#
# Structure & Details:
#
# Features: 5 features (CustomerID, Gender, Age, Annual Income (k$), and Spending Score (1-100)).
# Data Type: A mix of categorical data (Gender) and numerical features (Age, Annual Income, Spending Score).
# Labeling: It is unlabeled. There is no predefined "target" or "group" column; the objective is to use unsupervised learning (like K-Means) to discover natural customer segments based on their income and spending behaviors.
